# %% [markdown]
# # 1.传入数据

# %%
import pandas as pd
test=pd.read_csv('D:\\dataset\\house-prices-advanced-regression-techniques\\test.csv')
train=pd.read_csv('D:\\dataset\\house-prices-advanced-regression-techniques\\train.csv')

# 查看训练集和测试集的样本量
ntrain=train.shape[0]
ntest=test.shape[0]
# 查看训练集的标签
y_train=train.SalePrice.values
y_train
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500], dtype=int64)

# %%
data=pd.concat([train,test],axis=0,sort=False)
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # 2.数据预处理
# ## 2.1 查看缺失值
# 查看哪些特征列的缺失值严重，比如找出特征列缺失值超过一般的特征。需要把这些列剔除，

# %%
# 删去了缺失值比例大于50%的特征列
# drop()表示删除的列的列表，axis=1表示删除的是列。
missing_data=[c for c in data if data[c].isna().mean()*100>50]
data=data.drop(missing_data,axis=1)

# %%
data
# 删除完后只有2919行
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %% [markdown]
# # 2.2 对缺失值进行填充

# %%
# 对类别型数据和数值型数据分别进行处理
object_df=data.select_dtypes(include=['object'])
numercial_df=data.select_dtypes(exclude=['object'])

# 对类别型缺失值用字符填充
object_df=object_df.fillna('unknow')

# 对数值型缺失值用中位数填充
missing_cols=[c for c in numercial_df if numercial_df[c].isnull().sum()>0]
for c in missing_cols:  
    numercial_df[c]=numercial_df[c].fillna(numercial_df[c].median())

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
# 把一些分布极不平衡的特征删去
object_df=object_df.drop(['Heating','RoofMatl','Condition2','Street','Utilities'],axis=1)

# %% [markdown]
# # 3.特征提取

# %% [markdown]
# ## 3.1 基本特征构造

# %%
# 基本特征构造, 添加二阶特征
numercial_df.loc[numercial_df['YrSold']<numercial_df['YearBuilt'],'YrSold']=2009
numercial_df['Age_House']=numercial_df['YrSold']-numercial_df['YearBuilt']

# %%
# 房屋的结构信息，比如房屋的总的浴池面积，浴室面积，房屋总面积
numercial_df['TolalBsmtBath']=numercial_df['BsmtFullBath']+numercial_df['BsmtHalfBath']*0.5
numercial_df['TotalBath']=numercial_df['FullBath']+numercial_df['HalfBath']*0.5
numercial_df['TotalSA']=numercial_df['TotalBsmtSF']+numercial_df['1stFlrSF']+numercial_df['2ndFlrSF']

# %% [markdown]
# ## 3.2 特征编码

# %%
# 对object类的特征进行编码处理
bin_map={'TA':2,'Gd':3,'Fa':1,'Ex':4,'Po':1,'None':0,'Y':1,
        'N':0,'Reg':3,'IR1':2,'IR2':1,'IR3':0,'None':0,'No':0,'Mn':2,
        'Av':3,'Gd':4,'Unf':1,'LwQ':2,'Rec':3,'BLQ':4,'ALQ':5,'GLQ':6}
object_df['ExterQual'] = object_df['ExterQual'].map(bin_map)
# 具体来说，它将ExtenQual列中的每个值都替换为bin_map字典中对应的值。
# 如果ExtenQual列中的某个值在bin_map字典中不存在，那么它将保持不变
# 使用 map() 函数将 bin_map 字典应用到 object_df 数据框的 ExtenQual 列上，从而实现对该列的编码处理。

# %%
object_df['ExterCond'] = object_df['ExterCond'].map(bin_map)
object_df['BsmtCond'] = object_df['BsmtCond'].map(bin_map)
object_df['BsmtQual'] = object_df['BsmtQual'].map(bin_map)
object_df['HeatingQC'] = object_df['HeatingQC'].map(bin_map)
object_df['KitchenQual'] = object_df['KitchenQual'].map(bin_map)
object_df['FireplaceQu'] = object_df['FireplaceQu'].map(bin_map)
object_df['GarageQual'] = object_df['GarageQual'].map(bin_map)
object_df['GarageCond'] = object_df['GarageCond'].map(bin_map)
object_df['CentralAir'] = object_df['CentralAir'].map(bin_map)
object_df['LotShape'] = object_df['LotShape'].map(bin_map)
object_df['BsmtExposure'] = object_df['BsmtExposure'].map(bin_map)
object_df['BsmtFinType1'] = object_df['BsmtFinType1'].map(bin_map)
object_df['BsmtFinType2'] = object_df['BsmtFinType2'].map(bin_map)

# %%
# 和上面的用法保持一致
avedDrive = {"N" : 0, "P" : 1, "Y" : 2}
object_df['PavedDrive'] = object_df['PavedDrive'].map(PavedDrive)

# %%
rest_object_columns = object_df.select_dtypes(include=['object'])
# 因为之前的部分进行编码的特征已经不是object类型了。
get_dummies(对某些列进行进行独热编码)
object_df=pd.get_dummies(object_df,columns=rest_object_columns.columns)
data=pd.concat([object_df,numercial_df],axis=1)
data
# Out:
#       LotShape  ExterQual  ExterCond  BsmtQual  BsmtCond  BsmtExposure  \
# 0            3          4          2       4.0       2.0           0.0
# 1            3          2          2       4.0       2.0           4.0
# 2            2          4          2       4.0       2.0           2.0
# 3            2          2          2       2.0       4.0           0.0
# 4            2          4          2       4.0       2.0           3.0
# ...        ...        ...        ...       ...       ...           ...
# 1454         3          2          2       2.0       2.0           0.0
# 1455         3          2          2       2.0       2.0           0.0
# 1456         3          2          2       2.0       2.0           0.0
# 1457         3          2          2       4.0       2.0           3.0
# 1458         3          2          2       4.0       2.0           3.0
#
#       BsmtFinType1  BsmtFinType2  HeatingQC  CentralAir  ...  ScreenPorch  \
# ...

# %% [markdown]
# 整个特征处理过程包括以下几个步骤：<br>
# 1.基本特征的构造 <br>
# 2.对类别型特征进行编码，一种是自然编码，通过构造字典和使用 map()函数进行自然编码.除此之外，使用get_dummies()函数进行one-hot编码。

# %% [markdown]
# # 4.特征选择<br>
# 使用相关性评估的方式进行特征选择，过滤掉相似性大于一定阈值的特征，减少特征冗余。

# %%
def correlation(date,threshold):
    col_corr=set()
    corr_matrix=date.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                # 其实就是对相关性矩阵的左下方进行判断
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
# 筛选出所有的特征，注意saleprice是标签
all_cols=[c for c in data.columns if c not in ['SalePrice']]
cor_features=correlation(data[all_cols],0.9)
cor_features
# Out:
# {'Age_House',
#  'Exterior2nd_CmentBd',
#  'Exterior2nd_MetalSd',
#  'Exterior2nd_VinylSd',
#  'Exterior2nd_unknow',
#  'GarageFinish_unknow',
#  'LandSlope_Mod',
#  'RoofStyle_Hip',
#  'SaleCondition_Partial',
#  'TolalBsmtBath',
#  'TotalBath'}
